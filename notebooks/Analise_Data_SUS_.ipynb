# %% [markdown]
# <a href="https://colab.research.google.com/github/Senna-m/chagas-disease-data-analysis/blob/main/Analise_Data_SUS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_RegiaoXFaixa = pd.read_csv('/content/Doença de Chagas - Regiao X Faixa Etaria.csv',sep=';')
display(df_RegiaoXFaixa.head())
# Out:
#    Regiao de notificacao  <1 Ano  1-4  5-9 10-14 15-19  20-39  40-59  60-64  \
# 0         1 Regiao Norte      53  190  328   380   378   1499   1087    155
# 1      2 Regiao Nordeste       1    7   10    12    11     52     46      6
# 2       3 Regiao Sudeste       7    2    1     -     1      3      4      2
# 3           4 Regiao Sul       4    2    -     -     -      4      3      1
# 4  5 Regiao Centro-Oeste       1    -    -     -     -      9     24      1
#
#   65-69 70-79  80 e +  Total
# 0   122   150      44   4386
# 1     6     7       4    162
# 2     1     1       2     24
# 3     -     -       1     15
# 4     3     1       1     40

# %%
df_RegiaoXAno = pd.read_csv('/content/Doença de Chagas - Regiao X Ano.csv',sep=';')
display(df_RegiaoXAno.head())
# Out:
#    Regiao de notificacao 2009 2010 2011 2012  2013  2014 2015 2016 2017 2018  \
# 0         1 Regiao Norte   17  112  148  196   146   205  269  355  332  355
# 1      2 Regiao Nordeste    3    9   14    -     2     1   19    3    1   29
# 2       3 Regiao Sudeste    -    -    -    2     2     1    -    1    2    -
# 3           4 Regiao Sul    -    1    -    1     1     1    -    -    -    -
# 4  5 Regiao Centro-Oeste    1   14    8    -     1     1    -    -    3    -
#
#   2019 2020  2021  2022  2023  2024  Total
# 0  350  162   324   387   526   502   4386
# 1   32    1     9    16     9    14    162
# 2    -    4     1     7     3     1     24
# 3    -    -     4     2     4     1     15
# 4    3    1     2     3     1     2     40

# %% [markdown]
# Arquivo Região X Via

# %%
df_RegiaoXVia = pd.read_csv('/content/Doença de Chagas - Regiao X Via.csv',sep=';')
display(df_RegiaoXVia.head())
# Out:
#    Regiao de notificacao  Ign/Branco  Vetorial Vertical Acidental  Oral Outro  \
# 0         1 Regiao Norte         422       272        3         5  3680     4
# 1      2 Regiao Nordeste          40        29        -         1    92     -
# 2       3 Regiao Sudeste           8         2        8         2     1     3
# 3           4 Regiao Sul           2         3        4         1     2     3
# 4  5 Regiao Centro-Oeste          22        16        1         -     -     1
#
#    Total
# 0   4386
# 1    162
# 2     24
# 3     15
# 4     40

# %%
df_RegiaoXVia.dtypes
# Out:
# Regiao de notificacao    object
# Ign/Branco                int64
# Vetorial                  int64
# Vertical                 object
# Acidental                object
# Oral                     object
# Outro                    object
# Total                     int64
# dtype: object

# %%
df_RegiaoXVia = df_RegiaoXVia.replace('-', 0)

# %%
cols = ['Ign/Branco','Vetorial','Vertical','Acidental','Oral','Outro']

df_RegiaoXVia[cols] = df_RegiaoXVia[cols].apply(pd.to_numeric)

# %% [markdown]
# Arquivo Obito Região X Ano

# %%
df_ObitoXAno = pd.read_csv('/content/Doenca de Chagas - OBITOS - Regiao X Ano.csv',sep=';')

# %%
df_ObitoXAno.dtypes
# Out:
# Regiao    object
# 2010       int64
# 2011       int64
# 2012       int64
# 2013       int64
# 2014       int64
# 2015       int64
# 2016       int64
# 2017       int64
# 2018       int64
# 2019       int64
# 2020       int64
# 2021       int64
# 2022       int64
# 2023       int64
# 2024       int64
# Total      int64
# dtype: object

# %% [markdown]
# Arquivo Obito Região X Faixa

# %%
df_ObitoXFaixa = pd.read_csv('/content/Doenca de Chagas - Obitos - Regiao X Faixa.csv',sep=';')

# %%
df_ObitoXFaixa.dtypes
# Out:
# Regiao             object
# Menor 1 ano        object
# 1 a 4 anos         object
# 5 a 9 anos         object
# 10 a 14 anos       object
# 15 a 19 anos       object
# 20 a 29 anos        int64
# 30 a 39 anos        int64
# 40 a 49 anos      float64
# 50 a 59 anos      float64
# 60 a 69 anos      float64
# 70 a 79 anos      float64
# 80 anos e mais    float64
# Idade ignorada     object
# Total             float64
# dtype: object

# %%
df_ObitoXFaixa = df_ObitoXFaixa.replace('-', 0)

# %%
df_ObitoXFaixa.head()
# Out:
#                   Regiao Menor 1 ano 1 a 4 anos 5 a 9 anos 10 a 14 anos  \
# 0         1 Regiao Norte           1          5          8           11
# 1      2 Regiao Nordeste           0          0          1            3
# 2       3 Regiao Sudeste           2          1          0            1
# 3           4 Regiao Sul           0          1          0            0
# 4  5 Regiao Centro-Oeste           0          0          0            1
#
#   15 a 19 anos  20 a 29 anos  30 a 39 anos  40 a 49 anos  50 a 59 anos  \
# 0            4            16            37          90.0         175.0
# 1           11            82           471        1268.0        2660.0
# 2           11            84           490        1963.0        4045.0
# 3            0             6            22          99.0         369.0
# 4            3            32           233           NaN           NaN
#
#    60 a 69 anos  70 a 79 anos  80 anos e mais Idade ignorada    Total
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_RegiaoXFaixa.plot(x='Regiao de notificacao', y='Total', kind='bar')

plt.title("Casos de Doença de Chagas por Região")
plt.xlabel("Região")
plt.ylabel("Total de Casos")

plt.show()

# %%
df_RegiaoXVia.head()
# Out:
#    Regiao de notificacao  Ign/Branco  Vetorial  Vertical  Acidental  Oral  \
# 0         1 Regiao Norte         422       272         3          5  3680
# 1      2 Regiao Nordeste          40        29         0          1    92
# 2       3 Regiao Sudeste           8         2         8          2     1
# 3           4 Regiao Sul           2         3         4          1     2
# 4  5 Regiao Centro-Oeste          22        16         1          0     0
#
#    Outro  Total
# 0      4   4386
# 1      0    162
# 2      3     24
# 3      3     15
# 4      1     40

# %%
df_RegiaoXVia.set_index('Regiao de notificacao')[[
    'Ign/Branco',
    'Vetorial',
    'Vertical',
    'Acidental',
    'Oral',
    'Outro'
]].plot(
    kind='bar',
    stacked=True,
    figsize=(10,6)
)

plt.title("Tipos de Transmissão da Doença de Chagas por Região")
plt.xlabel("Região")
plt.ylabel("Casos")

plt.show()
